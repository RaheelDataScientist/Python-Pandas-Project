# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\DELL\Downloads\countries.csv')
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
df.shape
# Out:
# (1704, 3)

# %%
df.shape[0]
# Out:
# 1704

# %%
df.shape[1]
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 40.1+ KB

# %%
df.describe()
# Out:
#              year    population
# count  1704.00000  1.704000e+03
# mean   1979.50000  2.960121e+07
# std      17.26533  1.061579e+08
# min    1952.00000  6.001100e+04
# 25%    1965.75000  2.793664e+06
# 50%    1979.50000  7.023596e+06
# 75%    1993.25000  1.958522e+07
# max    2007.00000  1.318683e+09

# %%
df.isnull()
# Out:
#       country   year  population
# 0       False  False       False
# 1       False  False       False
# 2       False  False       False
# 3       False  False       False
# 4       False  False       False
# ...       ...    ...         ...
# 1699    False  False       False
# 1700    False  False       False
# 1701    False  False       False
# 1702    False  False       False
# 1703    False  False       False
#
# [1704 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# country       0
# year          0
# population    0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
c_52 = df.loc[df['year'] == 1952]

# %%
c_07 = df.loc[df['year'] == 2007]

# %%
c_52
# Out:
#                  country  year  population
# 0            Afghanistan  1952     8425333
# 12               Albania  1952     1282697
# 24               Algeria  1952     9279525
# 36                Angola  1952     4232095
# 48             Argentina  1952    17876956
# ...                  ...   ...         ...
# 1644             Vietnam  1952    26246839
# 1656  West Bank and Gaza  1952     1030585
# 1668         Yemen, Rep.  1952     4963829
# 1680              Zambia  1952     2672000
# 1692            Zimbabwe  1952     3080907
#
# [142 rows x 3 columns]

# %%
c_07
# Out:
#                  country  year  population
# 11           Afghanistan  2007    31889923
# 23               Albania  2007     3600523
# 35               Algeria  2007    33333216
# 47                Angola  2007    12420476
# 59             Argentina  2007    40301927
# ...                  ...   ...         ...
# 1655             Vietnam  2007    85262356
# 1667  West Bank and Gaza  2007     4018332
# 1679         Yemen, Rep.  2007    22211743
# 1691              Zambia  2007    11746035
# 1703            Zimbabwe  2007    12311143
#
# [142 rows x 3 columns]

# %%
type(c_07), c_07.shape, type(c_52), c_52.shape
# Out:
# (pandas.core.frame.DataFrame, (142, 3), pandas.core.frame.DataFrame, (142, 3))

# %%
pop_growth = c_52.merge(c_07, left_on='country', right_on = 'country')

# %%
pop_growth.head(50)
# Out:
#                      country  year_x  population_x  year_y  population_y
# 0                Afghanistan    1952       8425333    2007      31889923
# 1                    Albania    1952       1282697    2007       3600523
# 2                    Algeria    1952       9279525    2007      33333216
# 3                     Angola    1952       4232095    2007      12420476
# 4                  Argentina    1952      17876956    2007      40301927
# 5                  Australia    1952       8691212    2007      20434176
# 6                    Austria    1952       6927772    2007       8199783
# 7                    Bahrain    1952        120447    2007        708573
# 8                 Bangladesh    1952      46886859    2007     150448339
# 9                    Belgium    1952       8730405    2007      10392226
# 10                     Benin    1952       1738315    2007       8078314
# 11                   Bolivia    1952       2883315    2007       9119152
# ...

# %%
pop_growth.drop(['year_x', 'year_y'], axis = 1)
pop_growth.head(50)
# Out:
#                      country  year_x  population_x  year_y  population_y
# 0                Afghanistan    1952       8425333    2007      31889923
# 1                    Albania    1952       1282697    2007       3600523
# 2                    Algeria    1952       9279525    2007      33333216
# 3                     Angola    1952       4232095    2007      12420476
# 4                  Argentina    1952      17876956    2007      40301927
# 5                  Australia    1952       8691212    2007      20434176
# 6                    Austria    1952       6927772    2007       8199783
# 7                    Bahrain    1952        120447    2007        708573
# 8                 Bangladesh    1952      46886859    2007     150448339
# 9                    Belgium    1952       8730405    2007      10392226
# 10                     Benin    1952       1738315    2007       8078314
# 11                   Bolivia    1952       2883315    2007       9119152
# ...

# %%
pop_growth.rename(columns={'population_x': 'population_52', 'population_y': 'population_07'}, inplace=True)

# %%
pop_growth.head(50)
# Out:
#                      country  year_x  population_52  year_y  population_07
# 0                Afghanistan    1952        8425333    2007       31889923
# 1                    Albania    1952        1282697    2007        3600523
# 2                    Algeria    1952        9279525    2007       33333216
# 3                     Angola    1952        4232095    2007       12420476
# 4                  Argentina    1952       17876956    2007       40301927
# 5                  Australia    1952        8691212    2007       20434176
# 6                    Austria    1952        6927772    2007        8199783
# 7                    Bahrain    1952         120447    2007         708573
# 8                 Bangladesh    1952       46886859    2007      150448339
# 9                    Belgium    1952        8730405    2007       10392226
# 10                     Benin    1952        1738315    2007        8078314
# ...

# %%
pop_growth.shape
# Out:
# (142, 5)

# %%
pop_growth.describe()
# Out:
#        year_x  population_52  year_y  population_07
# count   142.0   1.420000e+02   142.0   1.420000e+02
# mean   1952.0   1.695040e+07  2007.0   4.402122e+07
# std       0.0   5.810086e+07     0.0   1.476214e+08
# min    1952.0   6.001100e+04  2007.0   1.995790e+05
# 25%    1952.0   1.452026e+06  2007.0   4.508034e+06
# 50%    1952.0   3.943953e+06  2007.0   1.051753e+07
# 75%    1952.0   9.168198e+06  2007.0   3.121004e+07
# max    1952.0   5.562635e+08  2007.0   1.318683e+09

# %%
pop_growth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        142 non-null    object
#  1   year_x         142 non-null    int64
#  2   population_52  142 non-null    int64
#  3   year_y         142 non-null    int64
#  4   population_07  142 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 5.7+ KB

# %%
pop_growth.isnull()
# Out:
#      country  year_x  population_52  year_y  population_07
# 0      False   False          False   False          False
# 1      False   False          False   False          False
# 2      False   False          False   False          False
# 3      False   False          False   False          False
# 4      False   False          False   False          False
# ..       ...     ...            ...     ...            ...
# 137    False   False          False   False          False
# 138    False   False          False   False          False
# 139    False   False          False   False          False
# 140    False   False          False   False          False
# 141    False   False          False   False          False
#
# [142 rows x 5 columns]

# %%
pop_growth.isnull()
# Out:
#      country  year_x  population_52  year_y  population_07
# 0      False   False          False   False          False
# 1      False   False          False   False          False
# 2      False   False          False   False          False
# 3      False   False          False   False          False
# 4      False   False          False   False          False
# ..       ...     ...            ...     ...            ...
# 137    False   False          False   False          False
# 138    False   False          False   False          False
# 139    False   False          False   False          False
# 140    False   False          False   False          False
# 141    False   False          False   False          False
#
# [142 rows x 5 columns]

# %%
pop_growth.isnull().sum()
# Out:
# country          0
# year_x           0
# population_52    0
# year_y           0
# population_07    0
# dtype: int64

# %%
type(pop_growth)
# Out:
# pandas.core.frame.DataFrame

# %%
if 'year_x' in pop_growth.columns and 'year_y' in pop_growth.columns:
    pop_growth.drop(['year_x', 'year_y'], axis=1, inplace=True)
else:
    print("Columns 'year_x' and/or 'year_y' not found in the DataFrame.")
# Out:
# Columns 'year_x' and/or 'year_y' not found in the DataFrame.

# %%
pop_growth.head(50)
# Out:
#                      country  population_52  population_07
# 0                Afghanistan        8425333       31889923
# 1                    Albania        1282697        3600523
# 2                    Algeria        9279525       33333216
# 3                     Angola        4232095       12420476
# 4                  Argentina       17876956       40301927
# 5                  Australia        8691212       20434176
# 6                    Austria        6927772        8199783
# 7                    Bahrain         120447         708573
# 8                 Bangladesh       46886859      150448339
# 9                    Belgium        8730405       10392226
# 10                     Benin        1738315        8078314
# 11                   Bolivia        2883315        9119152
# 12    Bosnia and Herzegovina        2791000        4552198
# 13                  Botswana         442308        1639131
# 14                    Brazil       56602560      190010647
# ...

# %%
pop_growth['population_growth'] = pop_growth['population_07'] - pop_growth['population_52']

# %%
pop_growth.head(50)
# Out:
#                      country  population_52  population_07  population_growth
# 0                Afghanistan        8425333       31889923           23464590
# 1                    Albania        1282697        3600523            2317826
# 2                    Algeria        9279525       33333216           24053691
# 3                     Angola        4232095       12420476            8188381
# 4                  Argentina       17876956       40301927           22424971
# 5                  Australia        8691212       20434176           11742964
# 6                    Austria        6927772        8199783            1272011
# 7                    Bahrain         120447         708573             588126
# 8                 Bangladesh       46886859      150448339          103561480
# 9                    Belgium        8730405       10392226            1661821
# 10                     Benin        1738315        8078314            6339999
# ...

# %%
23464590 - 8425333
# Out:
# 15039257

# %%
31889923 - 842533
# Out:
# 31047390

# %%
31889923 - 8425333
# Out:
# 23464590

# %%
pop_growth = pop_growth.sort_values('population_growth', ascending=False).head(50)

# %%
pop_growth
# Out:
#               country  population_52  population_07  population_growth
# 24              China      556263527     1318683096          762419569
# 58              India      372000000     1110396331          738396331
# 134     United States      157553000      301139947          143586947
# 59          Indonesia       82052000      223547000          141495000
# 14             Brazil       56602560      190010647          133408087
# 97           Pakistan       41346560      169270617          127924057
# 8          Bangladesh       46886859      150448339          103561480
# 94            Nigeria       33119096      135031164          101912068
# 82             Mexico       30144317      108700891           78556574
# 101       Philippines       22438691       91077287           68638596
# 137           Vietnam       26246839       85262356           59015517
# 38              Egypt       22223309       80264543           58041234
# ...

# %%
pop_growth = pop_growth.reset_index()

# %%
pop_growth
# Out:
#     index           country  population_52  population_07  population_growth
# 0      24             China      556263527     1318683096          762419569
# 1      58             India      372000000     1110396331          738396331
# 2     134     United States      157553000      301139947          143586947
# 3      59         Indonesia       82052000      223547000          141495000
# 4      14            Brazil       56602560      190010647          133408087
# 5      97          Pakistan       41346560      169270617          127924057
# 6       8        Bangladesh       46886859      150448339          103561480
# 7      94           Nigeria       33119096      135031164          101912068
# 8      82            Mexico       30144317      108700891           78556574
# 9     101       Philippines       22438691       91077287           68638596
# 10    137           Vietnam       26246839       85262356           59015517
# ...

# %%
pop_growth = pop_growth.drop(['index'], axis = 1)

# %%
pop_growth.head(5)
# Out:
#          country  population_52  population_07  population_growth
# 0          China      556263527     1318683096          762419569
# 1          India      372000000     1110396331          738396331
# 2  United States      157553000      301139947          143586947
# 3      Indonesia       82052000      223547000          141495000
# 4         Brazil       56602560      190010647          133408087

# %%
plt.figure(figsize=(10, 10))
top_countries = ['China', 'India', 'USA', 'Indonesia', 'Brazil']
pop_growth = pop_growth['population_growth']
